# %% [markdown]
# # Validation of loan_type

# %%
import sqlalchemy 
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import *

# %%
end_date=datetime(2021,6,30)
start_date=end_date-relativedelta(months=11)
start_date=start_date.strftime('%Y-%m-01')
start_date
provision_type=[2,3,4,5]

# %%
pd.set_option('display.float_format', '{:.10f}'.format)

# %%
# df_loan_master
engine=sqlalchemy.create_engine("mysql+pymysql://sony:Extenso@123@10.13.189.55/dax_raw")
df_loan_master=pd.read_sql('fc_loan_facts',con=engine)
df_loan_master["is_bad_loan"]=np.select(
    [
        df_loan_master["provision_type"].isin(provision_type)
    ],
    [
        1
    ],
    default=0
)
df_loan_master
# Out:
#           id                             customer_code  \
# 0          1  ef9645272f09db5e25f1c4fea61c9235fb7a4aa0
# 1          2  0a76f6dbd164837f3f1f47ab2f87ebfb78553ec9
# 2          3  ec059473a0c139488a7c20a25decf2c76740b867
# 3          4  9598a050b55fae21c9875f56f06232ac45ba7cc2
# 4          5  872a9561e721e5f6047ffc2f17424c19764374fc
# ...      ...                                       ...
# 38172  38173  28316abb9d581c336dfcdaca3da87e1675ec8832
# 38173  38174  e5792b67d395feb9646a01a98273fb776d1d32cd
# 38174  38175  75720a7b1f9d2118ee1c39d8ca014873a1312838
# 38175  38176  f6eca58886d75b8c61c9356da1d50e6c8b0893c0
# 38176  38177  67585b546a2b4638c78d54590d1265aaf0436310
#
#                                  account_number  provision_type  is_active  \
# 0      71ee063417494a5e5221fc39ab86203cbbcea801               0          0
# 1      13620de3d6681aa7aa58ebe6f7cf057d676ee704               0          0
# 2      20165260d277d4965de5b628beba26db4cf83f27               0          0
# ...

# %%
# df_loan_facts
engine=sqlalchemy.create_engine("mysql+pymysql://sony:Extenso@123@10.13.189.55/dax_facts")
df_loan_facts=pd.read_sql('fc_loan_facts',con=engine)
df_loan_facts=df_loan_facts[["account_number","customer_code","loan_type"]]
df_loan_facts
# Out:
#                                  account_number  \
# 0      37510daf503da8be50d1a694ea813cc293a131d2
# 1      f02e5e456104671d2c55180fe39bff373c0e584b
# 2      6c37f9c17de145cfbbe5b3a2f7cb6ee72b887f52
# 3      6a40d860e4fbe38f0893a4d95dc08e45752298ee
# 4      ceeed3ef3cd41ece9e852928326bf5ea2f774dcb
# ...                                         ...
# 38383  e7d5b5d58fb62c2ee8ebe5bf99302fe0f3bc466b
# 38384  c125ae917bd03597909275a3c2c4367ab222d9d8
# 38385  8fafbf183ace06af4264ea2b4a324934d1587f3d
# 38386  316307fdcd41076a5cb52096c33ca975777a3915
# 38387  f914e2e75cb3cf9f5dc01f27f3100296ce3f7339
#
#                                   customer_code  loan_type
# 0      001e72eb9f09076ecba9c749eccb13b41fdfeb36          9
# 1      001b99791028b7226b11b7186b135649430699f7          9
# 2      0004826f6afb29aacc7e5e6a67d0a3b857a64058          9
# 3      001b99791028b7226b11b7186b135649430699f7          9
# 4      0003da8d5a1a39201cbe97f8eb77049e104ed647          9
# ...

# %%
df_loan_customers=df_loan_master[["customer_code","is_bad_loan"]].groupby(["customer_code"]).agg(
    has_bad_loan=("is_bad_loan","max")
)
df_loan_customers["has_good_loan"]=1
df_loan_customers.reset_index(inplace=True)
df_loan_customers["loan_type"]=np.select(
    [
        df_loan_customers["has_bad_loan"]==1
    ],
    [
        1
    ],default=0
)
df_loan_customers
# Out:
#                                   customer_code  has_bad_loan  has_good_loan  \
# 0      0001037b42067f5937dfa085d1218633c95dc0c2             0              1
# 1      00059390196eb1e7bcf3311b1ba050b5322d96d5             0              1
# 2      00071a259ef3ca727f22e2892b6f4228cecac289             0              1
# 3      000c653228c38475179fac8281cd484f05ca6791             0              1
# 4      000ec0fc709998d1c81e2414590d5d51a527ae00             0              1
# ...                                         ...           ...            ...
# 28829  fff4255732b4fee957ee5626f1ebff4805873da6             0              1
# 28830  fff43bbcd935a3553b774ab3b592795e43157dcb             0              1
# 28831  fff851a4747d5bdbfb419a2480db9a3ef41867d9             0              1
# 28832  fffa0bc7da717124f481343095cd7992d7127083             0              1
# 28833  fffbe69321f70c7148ceb789ed348d6ee9d218f3             0              1
#
#        loan_type
# 0              0
# ...

# %%
df_qa_vs_dev=pd.merge(df_loan_customers,df_loan_facts,how="inner",on="customer_code",suffixes=('_qa','_dev'))
df_qa_vs_dev["status"]=np.select(
    [
        df_qa_vs_dev["loan_type_qa"]==df_qa_vs_dev["loan_type_dev"]
    ],
    [
        'Pass'
    ],
    default='Fail'
)
df_qa_vs_dev
# Out:
#                                  customer_code  has_bad_loan  has_good_loan  \
# 0     0039f8a5b5d4a22dc753222d132620b366372dbe             0              1
# 1     003ad80fa366ae257b11df97241918843229775c             0              1
# 2     00433e0abdc6db0118a51522a90b1d0acab16d49             0              1
# 3     005d37ff21c61ce1c8a72e0565bca87c435bbe87             0              1
# 4     0082ddfead73888bbdf166cc1462e303c38a2b77             0              1
# ...                                        ...           ...            ...
# 2001  ffb3a2f1a69dfcdf71bcd4aa43057eed3dcba917             0              1
# 2002  ffef0aab7a52e7b2113542fb61f964617741cedf             0              1
# 2003  fff15a065c6ed3e201088475e69a52213850b244             0              1
# 2004  fff4255732b4fee957ee5626f1ebff4805873da6             0              1
# 2005  fffa0bc7da717124f481343095cd7992d7127083             0              1
#
# ...

# %%
df_qa_vs_dev["status"].value_counts()
# Out:
# Pass    2006
# Name: status, dtype: int64

# %%
df_loan_facts["loan_type"].value_counts()
# Out:
# 9    36382
# 0     2006
# Name: loan_type, dtype: int64
